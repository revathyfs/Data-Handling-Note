# %%
import numpy as np

# %%
data=np.array([1,2,3,4,5])

# %%
data
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(data)
# Out:
# [1 2 3 4 5]

# %%
print(data[1:4])
# Out:
# [2 3 4]

# %%
print(data[::-1])
# Out:
# [5 4 3 2 1]

# %%
data[1]
# Out:
# np.int64(2)

# %%
print(data[1])
# Out:
# 2

# %%
data = np.array([1, 2, np.nan, 4, 5])

# %%
print(np.isnan(data))
# Out:
# [False False  True False False]

# %%
c=data[~np.isnan(data)]

# %%
c
# Out:
# array([1., 2., 4., 5.])

# %%
print(c)
# Out:
# [1. 2. 4. 5.]
