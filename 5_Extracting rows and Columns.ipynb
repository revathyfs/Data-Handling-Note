# %% [markdown]
# # pandas iloc

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# In **Pandas**, `.iloc[]` is used for **integer-location based indexing**—i.e., it allows you to access rows and columns by their **integer positions** (starting from 0).
#
# ---
#
# ### 🔹 Syntax:
#
# ```python
# df.iloc[row_index, column_index]
# ```
#
# You can use:
#
# * a single integer (e.g., `df.iloc[2]`)
# * a list of integers (e.g., `df.iloc[[1, 3]]`)
# * a slice (e.g., `df.iloc[1:4]`)
# * both row and column indices (e.g., `df.iloc[2, 1]`)
#
# ---
#
# ### 🔹 Example:
#
# ```python
# import pandas as pd
#
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie'],
#     'Age': [25, 30, 35],
#     'City': ['NY', 'LA', 'Chicago']
# }
#
# df = pd.DataFrame(data)
# ```
#
# #### ➤ Get 2nd row (index 1):
#
# ```python
# df.iloc[1]
# ```
#
# ✅ Output:
#
# ```
# Name    Bob
# Age      30
# City     LA
# Name: 1, dtype: object
# ```
#
# #### ➤ Get first two rows:
#
# ```python
# df.iloc[0:2]
# ```
#
# #### ➤ Get value at 3rd row, 2nd column:
#
# ```python
# df.iloc[2, 1]  # Returns 35
# ```
#
# #### ➤ Get values from specific rows and columns:
#
# ```python
# df.iloc[[0, 2], [0, 2]]
# ```
#
# This returns the Name and City of rows 0 and 2.
#
# ---
#
# ### 🔹 Difference from `.loc[]`:
#
# * `.iloc[]` → index **position**
# * `.loc[]` → index **label**
#
# ---

# %%
data= pd.read_csv("C:\\Users\\Hello\\OneDrive\\Desktop\\Ethqan\\ML\\titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #### 🔹 `pd`
#
# This is a common alias for the **Pandas** library. Usually at the top of your code you would have:
#
# ```python
# import pandas as pd
# ```
#
# So, `pd.read_csv()` means you're calling the `read_csv()` function from the Pandas library.
#
# ---
#
# #### 🔹 `read_csv('titanic.csv')`
#
# * `read_csv()` is a Pandas function used to **read a CSV (Comma-Separated Values) file** and load its contents into a **DataFrame**.
# * `'titanic.csv'` is the name of the file. It must be present in your **current working directory** (or you need to give the full path).
#
# The function reads the data from the CSV file and converts it into a structured table (a DataFrame) that you can work with easily in Python.
#
# ---
#
# #### 🔹 `data = ...`
#
# This assigns the resulting **DataFrame** (the loaded data) to the variable named `data`.
#
# So now, `data` holds your entire Titanic dataset, and you can use it to do analysis, filtering, visualization, etc.
#
# ---
#
# ### ✅ After this line:
#
# You can do things like:
#
# ```python
# data.head()        # First 5 rows
# data.columns       # List of column names
# data.shape         # Rows and columns
# data.describe()    # Statistics of numeric data
# data['Survived']   # Access the "Survived" column
# ```
#
# ---

# %% [raw]
# loc and iloc , for extracting the columns and rows

# %%
data.iloc[2]      #extracting rows
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %% [markdown]
# ### 🔍 Explanation:
#
# * `data` → This is your **DataFrame** containing the Titanic dataset (loaded from `'titanic.csv'`).
# * `.iloc[2]` → This accesses the **3rd row** (since counting starts at 0) **by its position**.
#
# So you're asking Pandas to return **the entire third row** (row at index position `2`) from the dataset.
#
# ---
#
# ### ✅ Output:
#
# You will get something like this (the actual values depend on the dataset version you're using):
#
# ```
# PassengerId      3
# Survived         1
# Pclass           3
# Name             Heikkinen, Miss. Laina
# Sex              female
# Age              26.0
# SibSp            0
# Parch            0
# Ticket           STON/O2. 3101282
# Fare             7.925
# Cabin            NaN
# Embarked         S
# Name: 2, dtype: object
# ```
#
# This is a **Series** (not a DataFrame), representing all the column values for the 3rd passenger.
#
# ---
#
# ### 🔁 If you want a DataFrame instead:
#
# Use double brackets:
#
# ```python
# data.iloc[[2]]
# ```
#
# This returns a **single-row DataFrame** instead of a Series.
#
# ---

# %%
data.iloc[[2]]    #passing as list,2-2nd row
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %% [markdown]
# # Selecting multiple rows using iloc

# %%
data.iloc[[2,4,6,8,10,15,78]]
# Out:
#     PassengerId  Survived  Pclass  \
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 15           16         1       2
# 78           79         1       2
#
#                                                  Name     Sex    Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.00      0
# 4                            Allen, Mr. William Henry    male  35.00      0
# 6                             McCarthy, Mr. Timothy J    male  54.00      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.00      0
# 78                      Caldwell, Master. Alden Gates    male   0.83      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 4       0            373450   8.0500   NaN        S
# 6       0             17463  51.8625   E46        S
# 8       2            347742  11.1333   NaN        S
# 10      1           PP 9549  16.7000    G6        S
# 15      0            248706  16.0000   NaN        S
# 78      2            248738  29.0000   NaN        S

# %% [markdown]
# ### 🔍 Explanation:
#
# * `data` is your Titanic dataset (a DataFrame).
# * `.iloc[]` is used for **integer-location based indexing**.
# * Inside the brackets, you're passing a **list of row indices**: `[2, 4, 6, 8, 10, 15, 78]`.
#
# ---
#
# ### ✅ What this does:
#
# It **retrieves specific rows** from the dataset—specifically the:
#
# * 3rd row (index 2)
# * 5th row (index 4)
# * 7th row (index 6)
# * 9th row (index 8)
# * 11th row (index 10)
# * 16th row (index 15)
# * 79th row (index 78)
#
# So you’ll get a **subset of 7 rows** from the DataFrame.
#
# ---
#
# ### 🧠 Use case:
#
# This is helpful when you want to manually **inspect specific passengers**, maybe based on IDs or patterns (like every alternate survivor, or certain ticket classes).
#
# ---

# %% [markdown]
# # slicing rows using iloc

# %%
data.iloc[1:8]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S

# %% [markdown]
# ---
#
# ### 🔍 Explanation:
#
# * `data` → Your Titanic dataset (a DataFrame).
# * `.iloc[1:8]` → This selects rows by their **integer position**, using **Python slicing**.
# * `1:8` → Means "from index 1 up to, but not including, index 8".
#
# ---
#
# ### ✅ What it does:
#
# It **returns rows at positions** 1, 2, 3, 4, 5, 6, and 7 — a total of **7 rows** from the dataset.
#
# ---
#
# ### 🧠 Use case:
#
# You use slicing like this when you want a **continuous block of rows**—for previewing data or batch processing.
#
# ---

# %%
data.iloc[2].values             #to get the values of a specified row
# Out:
# array([3, 1, 3, 'Heikkinen, Miss. Laina', 'female', 26.0, 0, 0,
#        'STON/O2. 3101282', 7.925, nan, 'S'], dtype=object)

# %% [markdown]
# ### 🔍 Explanation:
#
# * `data.iloc[2]` → Selects the **3rd row** from the DataFrame (by integer position).
# * `.values` → Converts that row (which is a **Pandas Series**) into a **NumPy array**.
#
# ---
#
# ### ✅ What you get:
#
# An array containing **all the values from row 2**, in the same order as the DataFrame columns.
#
# ---
#
# ### 🧠 Why use `.values`?
#
# * Converts a **row from Series format to array**, which is often useful for:
#
#   * Feeding data into ML models.
#   * Doing numerical or array-based operations.
#   * Avoiding label-based access.
#
# ---

# %%
data.iloc[:,10]    #colon represent to retrieve all the rows in the data and second number represent the column
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data.iloc[:,10].values
# Out:
# array([nan, 'C85', nan, 'C123', nan, nan, 'E46', nan, nan, nan, 'G6',
#        'C103', nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D56', nan,
#        'A6', nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'B78', nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'D33', nan, 'B30', 'C52', nan, nan, nan,
#        nan, nan, 'B28', 'C83', nan, nan, nan, 'F33', nan, nan, nan, nan,
#        nan, nan, nan, nan, 'F G73', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'E31', nan,
#        nan, nan, 'A5', 'D10 D12', nan, nan, nan, nan, 'D26', nan, nan,
#        nan, nan, nan, nan, nan, 'C110', nan, nan, nan, nan, nan, nan, nan,
#        'B58 B60', nan, nan, nan, nan, 'E101', 'D26', nan, nan, nan,
#        'F E69', nan, nan, nan, nan, nan, nan, nan, 'D47', 'C123', nan,
#        'B86', nan, nan, nan, nan, nan, nan, nan, nan, 'F2', nan, nan,
#        'C2', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, 'E33', nan, nan, nan, 'B19', nan, nan, nan, 'A7', nan,
#        nan, 'C49', nan, nan, nan, nan, nan, 'F4', nan, 'A32', nan, nan,
#        nan, nan, nan, nan, nan, 'F2', 'B4', 'B80', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'G6', nan, nan, nan, 'A31', nan, nan, nan,
#        nan, nan, 'D36', nan, nan, 'D15', nan, nan, nan, nan, nan, 'C93',
#        nan, nan, nan, nan, nan, 'C83', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, 'C78', nan, nan, 'D35', nan,
#        nan, 'G6', 'C87', nan, nan, nan, nan, 'B77', nan, nan, nan, nan,
#        'E67', 'B94', nan, nan, nan, nan, 'C125', 'C99', nan, nan, nan,
#        'C118', nan, 'D7', nan, nan, nan, nan, nan, nan, nan, nan, 'A19',
#        nan, nan, nan, nan, nan, nan, 'B49', 'D', nan, nan, nan, nan,
#        'C22 C26', 'C106', 'B58 B60', nan, nan, nan, 'E101', nan,
#        'C22 C26', nan, 'C65', nan, 'E36', 'C54', 'B57 B59 B63 B66', nan,
#        nan, nan, nan, nan, nan, 'C7', 'E34', nan, nan, nan, nan, nan,
#        'C32', nan, 'D', nan, 'B18', nan, 'C124', 'C91', nan, nan, nan,
#        'C2', 'E40', nan, 'T', 'F2', 'C23 C25 C27', nan, nan, nan, 'F33',
#        nan, nan, nan, nan, nan, 'C128', nan, nan, nan, nan, 'E33', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 'D37', nan, nan, 'B35',
#        'E50', nan, nan, nan, nan, nan, nan, 'C82', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, 'B96 B98', nan, nan, 'D36',
#        'G6', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'C78', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan

# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.iloc[:,0:6]       #all rows upto 5th column
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 6 columns]

# %%
data.iloc[0,0]     #0th row and 0th column
# Out:
# 1

# %%
data.iloc[3,[2,3,4]]
# Out:
# Pclass                                               1
# Name      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                             female
# Name: 3, dtype: object

# %% [raw]
# retrieving the subset of the cells

# %%
data.iloc[0:5,3:7]      #0 to5 rows, 3 to 6 columns
# Out:
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0

# %% [markdown]
# # Pandas loc

# %%
#loc takes the indexes as the arguments
# pandas loc behaves in the same manneras iloc and we retrieve  single row as series


data.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
data.loc[[1]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %% [markdown]
# # slicing rows by using loc

# %%
data.loc[1:5]     #1 and 5 are the rowsname/rowsindex
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
data.loc[[5,8,88,50]]
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 8             9         1       3
# 88           89         1       1
# 50           51         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 88                         Fortune, Miss. Mabel Helen  female  23.0      3
# 50                         Panula, Master. Juha Niilo    male   7.0      4
#
#     Parch   Ticket      Fare        Cabin Embarked
# 5       0   330877    8.4583          NaN        Q
# 8       2   347742   11.1333          NaN        S
# 88      2    19950  263.0000  C23 C25 C27        S
# 50      1  3101295   39.6875          NaN        S

# %% [markdown]
# # Selecting column names using loc

# %%
data.loc[:,'Sex'].head(20)
# Out:
# 0       male
# 1     female
# 2     female
# 3     female
# 4       male
# 5       male
# 6       male
# 7       male
# 8     female
# 9     female
# 10    female
# 11    female
# 12      male
# 13      male
# 14    female
# 15    female
# 16      male
# 17      male
# 18    female
# 19    female
# Name: Sex, dtype: object

# %%
data.loc[1:5,['Name','Sex']]
# Out:
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male

# %% [markdown]
# | Feature                     | `.iloc[]`                                 | `.loc[]`                                   |
# | --------------------------- | ----------------------------------------- | ------------------------------------------ |
# | Full Form                   | Integer Location                          | Label Location                             |
# | Selection Type              | Position-based (integer index)            | Label-based (index/column names)           |
# | Index Used                  | Integer index positions (0, 1, 2, ...)    | Index labels (can be strings, dates, etc.) |
# | Column Access               | By position                               | By label                                   |
# | Row Access                  | By integer row index                      | By row label                               |
# | Slicing End                 | Exclusive (like Python lists)             | Inclusive                                  |
# | When Index is Custom        | Use index numbers                         | Use actual index names                     |
# | Returns Error If            | Integer index is out of range             | Label/index not found                      |
# | Common Use Case             | General row/column extraction by position | Extract data using row/column names        |
# | Example – single row        | `df.iloc[2]` (3rd row)                    | `df.loc[2]` (row with label 2)             |
# | Example – column access     | `df.iloc[:, 0]` (1st column)              | `df.loc[:, 'Name']` (column named 'Name')  |
# | Example – slicing rows      | `df.iloc[1:4]` (rows 1 to 3)              | `df.loc[1:4]` (includes row with label 4)  |
# | Usage with Boolean Indexing | ❌ Not typical                             | ✅ Common and intuitive                     |

# %%
data.iloc[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
data.loc[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
